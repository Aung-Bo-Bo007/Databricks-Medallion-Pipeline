# %%
import os
import sys
from databricks.connect import DatabricksSession


os.environ["DATABRICKS_HOST"] = "https://dbc-eca9a387-3473.cloud.databricks.com"
os.environ["DATABRICKS_TOKEN"] = "dapib4e161127cec6da4ae630f2dd97cfce0"
os.environ["DATABRICKS_SERVERLESS_COMPUTE_ID"] = "auto" 
print(f"Current Python Version: {sys.version.split()[0]}")

# ၂။ Databricks Session Serverless Mode 
print("Initializing Databricks Session...")
try:
    # config  clusterId  (empty string) 
    spark = DatabricksSession.builder.config(
        "spark.databricks.clusterId", "" 
    ).remote(
        serverless=True
    ).getOrCreate()
    
    from databricks.sdk.runtime import dbutils
    print(" Databricks Session Initialized with Serverless.")
except Exception as e:
    print(f" Session Initialization Failed: {e}")
    raise e

print("\n---  Medallion Pipeline Orchestration Started ---")

# 3 Notebook Run 

BASE_PATH = "/Users/aungbobohtwenex4@gmail.com/notebooks"

try:
    # Bronze Layer
    print(" Step 1: Running Bronze Layer...")
    dbutils.notebook.run(f"{BASE_PATH}/01_Bronze_Layer", 0)
    print(" Bronze Layer Completed.")

    # Silver Layer
    print(" Step 2: Running Silver Layer...")
    dbutils.notebook.run(f"{BASE_PATH}/Silver_Process_Masking", 0)
    print(" Silver Layer Completed.")

    # Gold Layer
    print(" Step 3: Running Gold Layer...")
    dbutils.notebook.run(f"{BASE_PATH}/03_Gold_Layer", 0)
    print(" Gold Layer Completed.")

    print("\n---  ALL PIPELINE STAGES COMPLETED SUCCESSFULLY  ---")

except Exception as e:
    print(f"\n Pipeline stopped due to error.")
    print(f"Error Details: {e}")

# %%
# 00_Master_Pipeline.ipynb
from databricks.connect import DatabricksSession

# Session 
spark = DatabricksSession.builder.getOrCreate()

# Layer 
dbutils.notebook.run("notebooks/01_Bronze_Layer", 0)
dbutils.notebook.run("notebooks/Silver_Process_Masking", 0)
dbutils.notebook.run("notebooks/03_Gold_Layer", 0)

print("Master Pipeline completed successfully!")
# Out:
# c:\Users\ab.htwe\AppData\Local\Programs\Python\Python311\Lib\site-packages\databricks\connect\session.py:551: UserWarning: DB Connect 15.4.1 is unsupported with serverless. Use with caution!
# DB Connect 15.1 is recommended. Install the recommended version by running 'pip install --upgrade "databricks-connect==15.1.*"'.
#   warnings.warn(str(e), UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       4 # Session
#       5 spark = DatabricksSession.builder.getOrCreate()
#       6
#       7 # Layer
# ----> 8 dbutils.notebook.run("notebooks/01_Bronze_Layer", 0)
#       9 dbutils.notebook.run("notebooks/Silver_Process_Masking", 0)
#      10 dbutils.notebook.run("notebooks/03_Gold_Layer", 0)
#      11
#
# ...
